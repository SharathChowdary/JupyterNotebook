# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv(r"D:\programming languages\datasets\IPL\ipl.csv")

# %%
data
# Out:
#        mid        date                                      venue  \
# 0        1  2008-04-18                      M Chinnaswamy Stadium
# 1        1  2008-04-18                      M Chinnaswamy Stadium
# 2        1  2008-04-18                      M Chinnaswamy Stadium
# 3        1  2008-04-18                      M Chinnaswamy Stadium
# 4        1  2008-04-18                      M Chinnaswamy Stadium
# ...    ...         ...                                        ...
# 76009  617  2017-05-21  Rajiv Gandhi International Stadium, Uppal
# 76010  617  2017-05-21  Rajiv Gandhi International Stadium, Uppal
# 76011  617  2017-05-21  Rajiv Gandhi International Stadium, Uppal
# 76012  617  2017-05-21  Rajiv Gandhi International Stadium, Uppal
# 76013  617  2017-05-21  Rajiv Gandhi International Stadium, Uppal
#
#                     bat_team                    bowl_team      batsman  \
# 0      Kolkata Knight Riders  Royal Challengers Bangalore   SC Ganguly
# ...

# %%
stadiums=data.venue.unique()
stadiums
# Out:
# array(['M Chinnaswamy Stadium',
#        'Punjab Cricket Association Stadium, Mohali', 'Feroz Shah Kotla',
#        'Wankhede Stadium', 'Eden Gardens', 'Sawai Mansingh Stadium',
#        'Rajiv Gandhi International Stadium, Uppal',
#        'MA Chidambaram Stadium, Chepauk', 'Dr DY Patil Sports Academy',
#        'Newlands', "St George's Park", 'Kingsmead', 'SuperSport Park',
#        'Buffalo Park', 'New Wanderers Stadium', 'De Beers Diamond Oval',
#        'OUTsurance Oval', 'Brabourne Stadium',
#        'Sardar Patel Stadium, Motera', 'Barabati Stadium',
#        'Vidarbha Cricket Association Stadium, Jamtha',
#        'Himachal Pradesh Cricket Association Stadium', 'Nehru Stadium',
#        'Holkar Cricket Stadium',
#        'Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium',
#        'Subrata Roy Sahara Stadium',
#        'Shaheed Veer Narayan Singh International Stadium',
#        'JSCA International Stadium Complex', 'Sheikh Zayed Stadium',
# ...

# %%
data.head(50)
# Out:
#     mid        date                  venue               bat_team  \
# 0     1  2008-04-18  M Chinnaswamy Stadium  Kolkata Knight Riders
# 1     1  2008-04-18  M Chinnaswamy Stadium  Kolkata Knight Riders
# 2     1  2008-04-18  M Chinnaswamy Stadium  Kolkata Knight Riders
# 3     1  2008-04-18  M Chinnaswamy Stadium  Kolkata Knight Riders
# 4     1  2008-04-18  M Chinnaswamy Stadium  Kolkata Knight Riders
# 5     1  2008-04-18  M Chinnaswamy Stadium  Kolkata Knight Riders
# 6     1  2008-04-18  M Chinnaswamy Stadium  Kolkata Knight Riders
# 7     1  2008-04-18  M Chinnaswamy Stadium  Kolkata Knight Riders
# 8     1  2008-04-18  M Chinnaswamy Stadium  Kolkata Knight Riders
# 9     1  2008-04-18  M Chinnaswamy Stadium  Kolkata Knight Riders
# 10    1  2008-04-18  M Chinnaswamy Stadium  Kolkata Knight Riders
# 11    1  2008-04-18  M Chinnaswamy Stadium  Kolkata Knight Riders
# 12    1  2008-04-18  M Chinnaswamy Stadium  Kolkata Knight Riders
# ...

# %%
data.groupby("venue").mean()
# Out:
#                                                            mid       runs  \
# venue
# Barabati Stadium                                    296.203271  77.839953
# Brabourne Stadium                                   256.798551  84.055797
# Buffalo Park                                         80.721053  65.768421
# De Beers Diamond Oval                                88.646739  71.328804
# Dr DY Patil Sports Academy                          145.022989  66.997605
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Sta...  459.108715  71.816712
# Dubai International Cricket Stadium                 400.942396  71.014977
# Eden Gardens                                        337.177756  74.815577
# Feroz Shah Kotla                                    338.070175  77.968025
# Green Park                                          580.010163  81.343496
# Himachal Pradesh Cricket Association Stadium        260.531839  77.756951
# Holkar Cricket Stadium                              435.089141  72.914100
# ...

# %%
data1=data[['venue','bat_team','bowl_team','batsman','bowler','runs','wickets','overs','total']]

# %%
data1
# Out:
#                                            venue               bat_team  \
# 0                          M Chinnaswamy Stadium  Kolkata Knight Riders
# 1                          M Chinnaswamy Stadium  Kolkata Knight Riders
# 2                          M Chinnaswamy Stadium  Kolkata Knight Riders
# 3                          M Chinnaswamy Stadium  Kolkata Knight Riders
# 4                          M Chinnaswamy Stadium  Kolkata Knight Riders
# ...                                          ...                    ...
# 76009  Rajiv Gandhi International Stadium, Uppal         Mumbai Indians
# 76010  Rajiv Gandhi International Stadium, Uppal         Mumbai Indians
# 76011  Rajiv Gandhi International Stadium, Uppal         Mumbai Indians
# 76012  Rajiv Gandhi International Stadium, Uppal         Mumbai Indians
# 76013  Rajiv Gandhi International Stadium, Uppal         Mumbai Indians
#
#                          bowl_team      batsman        bowler  runs  wickets  \
# ...

# %%
grouped_data=data1.groupby('venue')

# %%
grouped_data.mean()
# Out:
#                                                          runs   wickets  \
# venue
# Barabati Stadium                                    77.839953  2.396028
# Brabourne Stadium                                   84.055797  1.965217
# Buffalo Park                                        65.768421  2.615789
# De Beers Diamond Oval                               71.328804  2.698370
# Dr DY Patil Sports Academy                          66.997605  3.281609
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Sta...  71.816712  2.255166
# Dubai International Cricket Stadium                 71.014977  2.633641
# Eden Gardens                                        74.815577  2.383317
# Feroz Shah Kotla                                    77.968025  2.491794
# Green Park                                          81.343496  2.806911
# Himachal Pradesh Cricket Association Stadium        77.756951  1.833184
# Holkar Cricket Stadium                              72.914100  2.607780
# ...

# %%
data.isna().sum()
# Out:
# mid               0
# date              0
# venue             0
# bat_team          0
# bowl_team         0
# batsman           0
# bowler            0
# runs              0
# wickets           0
# overs             0
# runs_last_5       0
# wickets_last_5    0
# striker           0
# non-striker       0
# total             0
# dtype: int64

# %%
data.bat_team.unique()
# Out:
# array(['Kolkata Knight Riders', 'Chennai Super Kings', 'Rajasthan Royals',
#        'Mumbai Indians', 'Deccan Chargers', 'Kings XI Punjab',
#        'Royal Challengers Bangalore', 'Delhi Daredevils',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Sunrisers Hyderabad',
#        'Rising Pune Supergiants', 'Gujarat Lions',
#        'Rising Pune Supergiant'], dtype=object)

# %%
active_teams=['Kolkata Knight Riders', 'Chennai Super Kings', 'Rajasthan Royals',
       'Mumbai Indians','Kings XI Punjab',
       'Royal Challengers Bangalore', 'Delhi Daredevils','Sunrisers Hyderabad']

# %%
data1=data[data.bat_team.isin(active_teams) & data.bowl_team.isin(active_teams)]

# %%
data.venue.unique()
# Out:
# array(['M Chinnaswamy Stadium',
#        'Punjab Cricket Association Stadium, Mohali', 'Feroz Shah Kotla',
#        'Wankhede Stadium', 'Eden Gardens', 'Sawai Mansingh Stadium',
#        'Rajiv Gandhi International Stadium, Uppal',
#        'MA Chidambaram Stadium, Chepauk', 'Dr DY Patil Sports Academy',
#        'Newlands', "St George's Park", 'Kingsmead', 'SuperSport Park',
#        'Buffalo Park', 'New Wanderers Stadium', 'De Beers Diamond Oval',
#        'OUTsurance Oval', 'Brabourne Stadium',
#        'Sardar Patel Stadium, Motera', 'Barabati Stadium',
#        'Vidarbha Cricket Association Stadium, Jamtha',
#        'Himachal Pradesh Cricket Association Stadium', 'Nehru Stadium',
#        'Holkar Cricket Stadium',
#        'Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium',
#        'Subrata Roy Sahara Stadium',
#        'Shaheed Veer Narayan Singh International Stadium',
#        'JSCA International Stadium Complex', 'Sheikh Zayed Stadium',
# ...

# %%
stadiums=['M Chinnaswamy Stadium',
       'Punjab Cricket Association Stadium, Mohali', 'Feroz Shah Kotla',
       'Wankhede Stadium', 'Eden Gardens', 'Sawai Mansingh Stadium',
       'Rajiv Gandhi International Stadium, Uppal',
       'MA Chidambaram Stadium, Chepauk', 'Dr DY Patil Sports Academy','Himachal Pradesh Cricket Association Stadium','Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium','Maharashtra Cricket Association Stadium']

# %%
data2=data1[data1.venue.isin(stadiums)]
data2
# Out:
#        mid        date                  venue               bat_team  \
# 0        1  2008-04-18  M Chinnaswamy Stadium  Kolkata Knight Riders
# 1        1  2008-04-18  M Chinnaswamy Stadium  Kolkata Knight Riders
# 2        1  2008-04-18  M Chinnaswamy Stadium  Kolkata Knight Riders
# 3        1  2008-04-18  M Chinnaswamy Stadium  Kolkata Knight Riders
# 4        1  2008-04-18  M Chinnaswamy Stadium  Kolkata Knight Riders
# ...    ...         ...                    ...                    ...
# 75884  616  2017-05-19  M Chinnaswamy Stadium  Kolkata Knight Riders
# 75885  616  2017-05-19  M Chinnaswamy Stadium  Kolkata Knight Riders
# 75886  616  2017-05-19  M Chinnaswamy Stadium  Kolkata Knight Riders
# 75887  616  2017-05-19  M Chinnaswamy Stadium  Kolkata Knight Riders
# 75888  616  2017-05-19  M Chinnaswamy Stadium  Kolkata Knight Riders
#
#                          bowl_team      batsman      bowler  runs  wickets  \
# ...

# %%
data2.date.dtype
# Out:
# dtype('O')

# %%
data2.date=pd.to_datetime(data2.date)
# Out:
# C:\Users\Sharath chandra\anaconda3\lib\site-packages\pandas\core\generic.py:5494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
data2.date.dtype
# Out:
# dtype('<M8[ns]')

# %%
data3=data2.drop(['mid','batsman','bowler','striker','non-striker'],axis=1)
data3
# Out:
#             date                  venue               bat_team  \
# 0     2008-04-18  M Chinnaswamy Stadium  Kolkata Knight Riders
# 1     2008-04-18  M Chinnaswamy Stadium  Kolkata Knight Riders
# 2     2008-04-18  M Chinnaswamy Stadium  Kolkata Knight Riders
# 3     2008-04-18  M Chinnaswamy Stadium  Kolkata Knight Riders
# 4     2008-04-18  M Chinnaswamy Stadium  Kolkata Knight Riders
# ...          ...                    ...                    ...
# 75884 2017-05-19  M Chinnaswamy Stadium  Kolkata Knight Riders
# 75885 2017-05-19  M Chinnaswamy Stadium  Kolkata Knight Riders
# 75886 2017-05-19  M Chinnaswamy Stadium  Kolkata Knight Riders
# 75887 2017-05-19  M Chinnaswamy Stadium  Kolkata Knight Riders
# 75888 2017-05-19  M Chinnaswamy Stadium  Kolkata Knight Riders
#
#                          bowl_team  runs  wickets  overs  runs_last_5  \
# 0      Royal Challengers Bangalore     1        0    0.1            1
# ...

# %%
data4=pd.get_dummies(data3,columns=['venue','bat_team','bowl_team'],drop_first=True)
data4
# Out:
#             date  runs  wickets  overs  runs_last_5  wickets_last_5  total  \
# 0     2008-04-18     1        0    0.1            1               0    222
# 1     2008-04-18     1        0    0.2            1               0    222
# 2     2008-04-18     2        0    0.2            2               0    222
# 3     2008-04-18     2        0    0.3            2               0    222
# 4     2008-04-18     2        0    0.4            2               0    222
# ...          ...   ...      ...    ...          ...             ...    ...
# 75884 2017-05-19   106        9   18.1           29               4    107
# 75885 2017-05-19   107        9   18.2           29               4    107
# 75886 2017-05-19   107        9   18.3           28               4    107
# 75887 2017-05-19   107        9   18.4           24               4    107
# 75888 2017-05-19   107       10   18.5           23               5    107
#
#        venue_Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium  \
# ...

# %%
data4.reset_index(inplace=True)
data4
# Out:
#        index       date  runs  wickets  overs  runs_last_5  wickets_last_5  \
# 0          0 2008-04-18     1        0    0.1            1               0
# 1          1 2008-04-18     1        0    0.2            1               0
# 2          2 2008-04-18     2        0    0.2            2               0
# 3          3 2008-04-18     2        0    0.3            2               0
# 4          4 2008-04-18     2        0    0.4            2               0
# ...      ...        ...   ...      ...    ...          ...             ...
# 40971  75884 2017-05-19   106        9   18.1           29               4
# 40972  75885 2017-05-19   107        9   18.2           29               4
# 40973  75886 2017-05-19   107        9   18.3           28               4
# 40974  75887 2017-05-19   107        9   18.4           24               4
# 40975  75888 2017-05-19   107       10   18.5           23               5
#
# ...

# %%
data4.drop('index',axis=1,inplace=True)
data4
# Out:
#             date  runs  wickets  overs  runs_last_5  wickets_last_5  total  \
# 0     2008-04-18     1        0    0.1            1               0    222
# 1     2008-04-18     1        0    0.2            1               0    222
# 2     2008-04-18     2        0    0.2            2               0    222
# 3     2008-04-18     2        0    0.3            2               0    222
# 4     2008-04-18     2        0    0.4            2               0    222
# ...          ...   ...      ...    ...          ...             ...    ...
# 40971 2017-05-19   106        9   18.1           29               4    107
# 40972 2017-05-19   107        9   18.2           29               4    107
# 40973 2017-05-19   107        9   18.3           28               4    107
# 40974 2017-05-19   107        9   18.4           24               4    107
# 40975 2017-05-19   107       10   18.5           23               5    107
#
#        venue_Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium  \
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()

# %%
columns_to_be_scaled=['runs','wickets','overs','total']
scaled_columns=scaler.fit_transform(data3[columns_to_be_scaled])
scaled_df=pd.DataFrame(scaled_columns,columns=columns_to_be_scaled)
scaled_df
# Out:
#            runs  wickets     overs     total
# 0      0.004065      0.0  0.005102  0.865922
# 1      0.004065      0.0  0.010204  0.865922
# 2      0.008130      0.0  0.010204  0.865922
# 3      0.008130      0.0  0.015306  0.865922
# 4      0.008130      0.0  0.020408  0.865922
# ...         ...      ...       ...       ...
# 40971  0.430894      0.9  0.923469  0.223464
# 40972  0.434959      0.9  0.928571  0.223464
# 40973  0.434959      0.9  0.933673  0.223464
# 40974  0.434959      0.9  0.938776  0.223464
# 40975  0.434959      1.0  0.943878  0.223464
#
# [40976 rows x 4 columns]

# %%
data4.drop(columns_to_be_scaled,axis=1,inplace=True)
data4
# Out:
#             date  runs_last_5  wickets_last_5  \
# 0     2008-04-18            1               0
# 1     2008-04-18            1               0
# 2     2008-04-18            2               0
# 3     2008-04-18            2               0
# 4     2008-04-18            2               0
# ...          ...          ...             ...
# 40971 2017-05-19           29               4
# 40972 2017-05-19           29               4
# 40973 2017-05-19           28               4
# 40974 2017-05-19           24               4
# 40975 2017-05-19           23               5
#
#        venue_Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium  \
# 0                                                      0
# 1                                                      0
# 2                                                      0
# 3                                                      0
# 4                                                      0
# ...

# %%
data5=pd.concat([data4,scaled_df],axis=1)
data5
# Out:
#             date  runs_last_5  wickets_last_5  \
# 0     2008-04-18            1               0
# 1     2008-04-18            1               0
# 2     2008-04-18            2               0
# 3     2008-04-18            2               0
# 4     2008-04-18            2               0
# ...          ...          ...             ...
# 40971 2017-05-19           29               4
# 40972 2017-05-19           29               4
# 40973 2017-05-19           28               4
# 40974 2017-05-19           24               4
# 40975 2017-05-19           23               5
#
#        venue_Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium  \
# 0                                                      0
# 1                                                      0
# 2                                                      0
# 3                                                      0
# 4                                                      0
# ...

# %%
data3=data5

# %%
training_data=data3[data3.date.dt.year<2016].drop('date',axis=1)
training_data
# Out:
#        runs_last_5  wickets_last_5  \
# 0                1               0
# 1                1               0
# 2                2               0
# 3                2               0
# 4                2               0
# ...            ...             ...
# 34895           57               2
# 34896           56               2
# 34897           56               2
# 34898           58               2
# 34899           56               2
#
#        venue_Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium  \
# 0                                                      0
# 1                                                      0
# 2                                                      0
# 3                                                      0
# 4                                                      0
# ...                                                  ...
# 34895                                                  0
# 34896                                                  0
# ...

# %%
testing_data=data3[data3.date.dt.year>=2016].drop('date',axis=1)
testing_data
# Out:
#        runs_last_5  wickets_last_5  \
# 34900            4               0
# 34901            4               0
# 34902            5               0
# 34903            6               0
# 34904            6               0
# ...            ...             ...
# 40971           29               4
# 40972           29               4
# 40973           28               4
# 40974           24               4
# 40975           23               5
#
#        venue_Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium  \
# 34900                                                  0
# 34901                                                  0
# 34902                                                  0
# 34903                                                  0
# 34904                                                  0
# ...                                                  ...
# 40971                                                  0
# 40972                                                  0
# ...

# %%
x_train=training_data.drop(['total'],axis=1)
x_train
# Out:
#        runs_last_5  wickets_last_5  \
# 0                1               0
# 1                1               0
# 2                2               0
# 3                2               0
# 4                2               0
# ...            ...             ...
# 34895           57               2
# 34896           56               2
# 34897           56               2
# 34898           58               2
# 34899           56               2
#
#        venue_Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium  \
# 0                                                      0
# 1                                                      0
# 2                                                      0
# 3                                                      0
# 4                                                      0
# ...                                                  ...
# 34895                                                  0
# 34896                                                  0
# ...

# %%
x_test=testing_data.drop('total',axis=1)
x_test
# Out:
#        runs_last_5  wickets_last_5  \
# 34900            4               0
# 34901            4               0
# 34902            5               0
# 34903            6               0
# 34904            6               0
# ...            ...             ...
# 40971           29               4
# 40972           29               4
# 40973           28               4
# 40974           24               4
# 40975           23               5
#
#        venue_Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium  \
# 34900                                                  0
# 34901                                                  0
# 34902                                                  0
# 34903                                                  0
# 34904                                                  0
# ...                                                  ...
# 40971                                                  0
# 40972                                                  0
# ...

# %%
y_train=training_data.total
y_train
# Out:
# 0        0.865922
# 1        0.865922
# 2        0.865922
# 3        0.865922
# 4        0.865922
#            ...
# 34895    0.754190
# 34896    0.754190
# 34897    0.754190
# 34898    0.754190
# 34899    0.754190
# Name: total, Length: 34900, dtype: float64

# %%
y_test=testing_data.total
y_test
# Out:
# 34900    0.173184
# 34901    0.173184
# 34902    0.173184
# 34903    0.173184
# 34904    0.173184
#            ...
# 40971    0.223464
# 40972    0.223464
# 40973    0.223464
# 40974    0.223464
# 40975    0.223464
# Name: total, Length: 6076, dtype: float64

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import r2_score

# %%
ridge = Ridge()
parameters={'alpha':[1e-15,1e-10,1e-8,1e-3,1e-2,1,5,10,20,30,35,40]}
ridge_regressor = RandomizedSearchCV(ridge,parameters,cv=10,scoring='neg_mean_squared_error')
ridge_regressor.fit(x_train,y_train)
# Out:
# C:\Users\Sharath chandra\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.31964e-22): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# C:\Users\Sharath chandra\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.31964e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# RandomizedSearchCV(cv=10, estimator=Ridge(),
#                    param_distributions={'alpha': [1e-15, 1e-10, 1e-08, 0.001,
#                                                   0.01, 1, 5, 10, 20, 30, 35,
#                                                   40]},
#                    scoring='neg_mean_squared_error')

# %%
ridge_regressor.score(x_test,y_test)
# Out:
# -0.011831959397677276

# %%
prediction_r = ridge_regressor.predict(x_test)
r2_score(y_test,prediction_r)
# Out:
# 0.541444571416551
